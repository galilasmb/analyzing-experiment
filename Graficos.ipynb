# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import datetime
import chardet
import time
from pandas.api.types import is_number
from matplotlib import pyplot as plt
import dask.dataframe as dd
import datetime

# %%
cont = 0
for i in range(102):
    if (cont%6)+1 == 6:
        print()
    else:
        print((cont%6)+1, "", end="")
   
    cont = cont + 1

# %%
colunas = ["Config CF source", "Confluence source", "Config CF sink", "Confluence sink", "Config OA", "OA", "Config DFP left", "DFP left", "Config DFP right", "DFP right", "Config PDG left", "PDG left", "Config PDG right", "PDG right"]

print(colunas)
# Out:
# ['Config CF source', 'Confluence source', 'Config CF sink', 'Confluence sink', 'Config OA', 'OA', 'Config DFP left', 'DFP left', 'Config DFP right', 'DFP right', 'Config PDG left', 'PDG left', 'Config PDG right', 'PDG right']

# %%
listColunas = {0: "Configure Soot Confluence 1", 1: "Time to perform Confluence 1",
               2: "Configure Soot Confluence 2", 3: "Time to perform Confluence 2",
               4: "Configure Soot OA Inter", 5: "Time to perform OA Inter",
               6: "Configure Soot DFP", 7: "Time to perform DFP",
               8: "Configure Soot DFP", 9: "Time to perform DFP",
               10: "Configure Soot PDG", 11: "Time to perform PDG",
               12: "Configure Soot PDG", 13: "Time to perform PDG"}
for (k, v) in listColunas.items():
    print(k, v)
# Out:
# 0 Configure Soot Confluence 1
# 1 Time to perform Confluence 1
# 2 Configure Soot Confluence 2
# 3 Time to perform Confluence 2
# 4 Configure Soot OA Inter
# 5 Time to perform OA Inter
# 6 Configure Soot DFP
# 7 Time to perform DFP
# 8 Configure Soot DFP
# 9 Time to perform DFP
# 10 Configure Soot PDG
# 11 Time to perform PDG
# 12 Configure Soot PDG
# 13 Time to perform PDG

# %%
def getValue(listColunas, value):
    for (k, v) in listColunas.items():
        if (v in value):
            return k
getValue(listColunas, "Time to perform Confluence 1 3412431s")
# Out:
# 1

# %%
df = pd.DataFrame(columns = colunas)
df.to_csv('resultTime.csv', header=True, sep=';', mode='a', index=False, encoding='utf-8-sig')

listColunas = {0: "Configure Soot Confluence 1", 1: "Time to perform Confluence 1",
               2: "Configure Soot Confluence 2", 3: "Time to perform Confluence 2",
               4: "Configure Soot OA Inter", 5: "Time to perform OA Inter",
               6: "Configure Soot DFP", 7: "Time to perform DFP",
               8: "Configure Soot DFP", 9: "Time to perform DFP",
               10: "Configure Soot PDG", 11: "Time to perform PDG",
               12: "Configure Soot PDG", 13: "Time to perform PDG"}

cont = 0
aux = []
with open("time.txt") as infile:
    chegouOA = False
    for i in infile:
        print(cont, i)
        
        if (str(listColunas.get(cont)) in str(i)):
            aux.append(i)
        else:
            pos = getValue(listColunas, str(i))
            while (cont < pos):
                print(str(listColunas.get(cont)), str(i))
                cont = cont + 1
                aux.append("0")
                print("Vazio")
                print(listColunas.get(0))
                if (cont%14)+1 == 1:
                    cont = 0
            aux.append(i)
            
        cont = cont + 1
 
        if (cont%14)+1 == 1:
            print("Salvando lista:", aux)
            df = pd.DataFrame([aux])
            df.to_csv('resultTime.csv', header=False, sep=';', mode='a', index=False, encoding='utf-8-sig')
            aux = []
            cont = 0
            temOA = False
print("Finalizou!")
print(cont)
# Out:
# 0 Configure Soot Confluence 1 6.72000s
#
# 1 Configure Soot OA Inter 6.98100s
#
# Time to perform Confluence 1 Configure Soot OA Inter 6.98100s
#
# Vazio
# Configure Soot Confluence 1
# Configure Soot Confluence 2 Configure Soot OA Inter 6.98100s
#
# Vazio
# Configure Soot Confluence 1
# Time to perform Confluence 2 Configure Soot OA Inter 6.98100s
#
# Vazio
# Configure Soot Confluence 1
# 6 Time to perform OA Inter 53393.04400s
#
# 8 Configure Soot DFP 7.71700s
#
# 9 Configure Soot DFP 7.81400s
#
# 11 Configure Soot PDG 5.33900s
#
# 13 Configure Soot PDG 7.25700s
#
# 15 Configure Soot Confluence 1 7.49400s
#
# 17 Time to perform Confluence 1 3.82200s
#
# 19 Configure Soot Confluence 2 4.00400s
#
# 21 Time to perform Confluence 2 0.55200s
#
# 23 Configure Soot OA Inter 7.19800s
#
# 25 Time to perform OA Inter 7.92600s
#
# 27 Configure Soot DFP 7.97300s
#
# 29 Time to perform DFP 21.64300s
#
# 31 Configure Soot PDG 5.91100s
#
# 33 Time to perform PDG 1.55800s
#
# 35 Configure Soot Confluence 1 5.18000s
#
# 37 Time to perform Confluence 1 0.87800s
#
# 39 Configure Soot Confluence 2 4.62000s
#
# 41 Time to perform Confluence 2 0.08500s
#
# 43 Configure Soot OA Inter 5.63600s
#
# 45 Time to perform OA Inter 5.78300s
#
# 47 Configure Soot DFP 5.96400s
#
# 49 Time to perform DFP 9.76100s
#
# 51 Configure Soot DFP 5.15600s
#
# 53 Time to perform DFP 10.22300s
#
# 55 Configure Soot PDG 6.30600s
#
# 57 Time to perform PDG 0.70800s
#
# 59 Configure Soot PDG 6.09800s
#
# 61 Time to perform PDG 0.86200s
#
# 63 Configure Soot Confluence 1 6.27200s
#
# 65 Time to perform Confluence 1 2.03600s
#
# 67 Configure Soot Confluence 2 4.18800s
#
# 69 Time to perform Confluence 2 0.03100s
#
# 71 Configure Soot OA Inter 5.94300s
#
# 73 Time to perform OA Inter 122050.96800s
#
# 75 Configure Soot DFP 5.39900s
#
# 77 Time to perform DFP 2.00200s
#
# 79 Configure Soot DFP 4.96900s
#
# 81 Time to perform DFP 0.34200s
#
# 83 Configure Soot PDG 6.02500s
#
# 85 Time to perform PDG 1.69200s
#
# 87 Configure Soot PDG 5.93800s
#
# 89 Time to perform PDG 0.47500s
#
# 91 Configure Soot Confluence 1 6.00300s
#
# 93 Time to perform Confluence 1 1.69300s
#
# 95 Configure Soot Confluence 2 4.21200s
#
# 97 Time to perform Confluence 2 0.05200s
#
# 99 Configure Soot OA Inter 5.88000s
#
# 101 Time to perform OA Inter 458546.13500s
#
# 103 Configure Soot DFP 5.23700s
#
# 105 Time to perform DFP 1.56600s
#
# 107 Configure Soot DFP 6.01600s
#
# 109 Time to perform DFP 0.40400s
#
# 111 Configure Soot PDG 7.60200s
#
# 113 Time to perform PDG 1.94700s
#
# 115 Configure Soot PDG 7.01400s
#
# 117 Time to perform PDG 0.37200s
#
# 119 Configure Soot Confluence 1 5.76900s
#
# 121 Time to perform Confluence 1 1.55100s
#
# 123 Configure Soot Confluence 2 4.12400s
#
# 125 Time to perform Confluence 2 0.05200s
#
# 127 Configure Soot OA Inter 6.47100s
#
# 129 Time to perform OA Inter 57074.67100s
#
# 131 Configure Soot DFP 6.12700s
#
# 133 Time to perform DFP 1.46100s
#
# 135 Configure Soot DFP 6.23000s
#
# 137 Time to perform DFP 0.47500s
#
# 139 Configure Soot PDG 5.70700s
#
# 141 Time to perform PDG 1.74600s
#
# 143 Configure Soot PDG 4.89300s
#
# 145 Time to perform PDG 0.40200s
#
# 147 Configure Soot Confluence 1 4.86900s
#
# 149 Time to perform Confluence 1 0.34400s
#
# 151 Configure Soot Confluence 2 3.97500s
#
# 153 Time to perform Confluence 2 0.04100s
#
# 155 Configure Soot OA Inter 6.20300s
#
# 157 Time to perform OA Inter 6.27500s
#
# 159 Configure Soot DFP 5.95000s
#
# 161 Time to perform DFP 0.64900s
#
# 163 Configure Soot DFP 6.10800s
#
# 165 Time to perform DFP 0.35900s
#
# 167 Configure Soot PDG 6.21700s
#
# 169 Time to perform PDG 0.37700s
#
# 171 Configure Soot PDG 5.62400s
#
# 173 Time to perform PDG 0.44200s
#
# 175 Configure Soot Confluence 1 0.75000s
#
# 177 Time to perform Confluence 1 0.66700s
#
# 179 Configure Soot Confluence 2 0.25200s
#
# 181 Time to perform Confluence 2 0.11800s
#
# 183 Configure Soot OA Inter 1.06100s
#
# 185 Time to perform OA Inter 1.47400s
#
# 187 Configure Soot DFP 1.08300s
#
# 189 Time to perform DFP 0.83900s
#
# 191 Configure Soot DFP 1.09000s
#
# 193 Time to perform DFP 0.89600s
#
# 195 Configure Soot PDG 1.10300s
#
# 197 Time to perform PDG 1.00000s
#
# 199 Configure Soot PDG 1.07100s
#
# 201 Time to perform PDG 1.01700s
#
# 203 Configure Soot Confluence 1 5.85300s
#
# 205 Time to perform Confluence 1 0.54300s
#
# 207 Configure Soot Confluence 2 4.10700s
#
# 209 Time to perform Confluence 2 0.16200s
#
# 211 Configure Soot OA Inter 4.97200s
#
# 213 Time to perform OA Inter 5.07500s
#
# 215 Configure Soot DFP 4.97000s
#
# 217 Time to perform DFP 0.80600s
#
# 219 Configure Soot DFP 7.12900s
#
# 221 Time to perform DFP 0.78500s
#
# 223 Configure Soot PDG 6.33100s
#
# 225 Time to perform PDG 0.79700s
#
# 227 Configure Soot PDG 5.68300s
#
# 229 Time to perform PDG 0.72400s
#
# 231 Configure Soot Confluence 1 6.88600s
#
# 233 Time to perform Confluence 1 0.36200s
#
# 235 Configure Soot Confluence 2 4.14600s
#
# 237 Time to perform Confluence 2 0.82100s
#
# 239 Configure Soot OA Inter 7.16400s
#
# 241 Time to perform OA Inter 7.26300s
#
# 243 Configure Soot DFP 6.43100s
#
# 245 Time to perform DFP 0.34100s
#
# 247 Configure Soot DFP 6.09000s
#
# 249 Time to perform DFP 1.85100s
#
# 251 Configure Soot PDG 5.00000s
#
# 253 Time to perform PDG 0.42400s
#
# 255 Configure Soot PDG 6.15000s
#
# 257 Time to perform PDG 0.91600s
#
# 259 Configure Soot Confluence 1 3.01500s
#
# 261 Time to perform Confluence 1 0.74700s
#
# 263 Configure Soot Confluence 2 1.96200s
#
# 265 Time to perform Confluence 2 0.13800s
#
# 267 Configure Soot OA Inter 3.11000s
#
# 269 Time to perform OA Inter 3.26200s
#
# 271 Configure Soot DFP 3.04600s
#
# 273 Time to perform DFP 1.09200s
#
# 275 Configure Soot DFP 3.02100s
#
# 277 Time to perform DFP 1.04000s
#
# 279 Configure Soot PDG 3.06000s
#
# 281 Time to perform PDG 0.95200s
#
# 283 Configure Soot PDG 2.97000s
#
# 285 Time to perform PDG 0.86600s
#
# 287 Configure Soot Confluence 1 6.17900s
#
# 289 Time to perform Confluence 1 1.58700s
#
# 291 Configure Soot Confluence 2 4.22200s
#
# 293 Time to perform Confluence 2 0.56700s
#
# 295 Configure Soot OA Inter 4.99200s
#
# 297 Time to perform OA Inter 6.89500s
#
# 299 Configure Soot DFP 6.86200s
#
# 301 Time to perform DFP 2.53500s
#
# 303 Configure Soot DFP 5.44900s
#
# 305 Time to perform DFP 1.70500s
#
# 307 Configure Soot PDG 5.42900s
#
# 309 Time to perform PDG 0.97500s
#
# 311 Configure Soot PDG 5.70000s
#
# 313 Time to perform PDG 1.02100s
#
# 315 Configure Soot Confluence 1 7.57600s
#
# 317 Time to perform Confluence 1 2.30100s
#
# 319 Configure Soot Confluence 2 5.12500s
#
# 321 Time to perform Confluence 2 0.57800s
#
# 323 Configure Soot OA Inter 6.01600s
#
# 325 Time to perform OA Inter 8.02800s
#
# 327 Configure Soot DFP 5.06900s
#
# 329 Time to perform DFP 2.17400s
#
# 331 Configure Soot DFP 5.60600s
#
# 333 Time to perform DFP 1.64800s
#
# 335 Configure Soot PDG 5.53900s
#
# 337 Time to perform PDG 1.06200s
#
# 339 Configure Soot PDG 6.71300s
#
# 341 Time to perform PDG 1.00100s
#
# 343 Configure Soot Confluence 1 0.85800s
#
# 345 Time to perform Confluence 1 0.55400s
#
# 347 Configure Soot Confluence 2 0.19300s
#
# 349 Time to perform Confluence 2 0.07200s
#
# 351 Configure Soot OA Inter 0.90900s
#
# 353 Time to perform OA Inter 1.01300s
#
# 355 Configure Soot DFP 0.82400s
#
# 357 Time to perform DFP 0.69700s
#
# 359 Configure Soot DFP 0.82600s
#
# 361 Time to perform DFP 0.79000s
#
# 363 Configure Soot PDG 0.83600s
#
# 365 Time to perform PDG 0.69600s
#
# 367 Configure Soot PDG 0.82100s
#
# 369 Time to perform PDG 0.71300s
#
# 371 Configure Soot Confluence 1 2.78400s
#
# 373 Time to perform Confluence 1 0.42200s
#
# 375 Configure Soot Confluence 2 1.30900s
#
# 377 Time to perform Confluence 2 0.13100s
#
# 379 Configure Soot OA Inter 3.21500s
#
# 381 Time to perform OA Inter 3.54700s
#
# 383 Configure Soot DFP 2.18200s
#
# 385 Time to perform DFP 0.64100s
#
# 387 Configure Soot DFP 3.10400s
#
# 389 Time to perform DFP 0.84200s
#
# 391 Configure Soot PDG 3.09900s
#
# 393 Time to perform PDG 0.65900s
#
# 395 Configure Soot PDG 2.75600s
#
# 397 Time to perform PDG 0.47400s
#
# 399 Configure Soot Confluence 1 1.06600s
#
# 401 Time to perform Confluence 1 0.53600s
#
# 403 Configure Soot Confluence 2 0.48100s
#
# 405 Time to perform Confluence 2 0.06200s
#
# 407 Configure Soot OA Inter 1.06600s
#
# 409 Time to perform OA Inter 1.16300s
#
# 411 Configure Soot DFP 1.02700s
#
# 413 Time to perform DFP 0.48300s
#
# 415 Configure Soot DFP 1.03400s
#
# 417 Time to perform DFP 0.52100s
#
# 419 Configure Soot PDG 1.08500s
#
# 421 Time to perform PDG 0.68700s
#
# 423 Configure Soot PDG 1.02900s
#
# 425 Time to perform PDG 0.60800s
#
# 427 Configure Soot Confluence 1 1.71100s
#
# 429 Time to perform Confluence 1 0.67900s
#
# 431 Configure Soot Confluence 2 1.03500s
#
# 433 Time to perform Confluence 2 0.07000s
#
# 435 Configure Soot OA Inter 1.80600s
#
# 437 Time to perform OA Inter 1.89200s
#
# 439 Configure Soot DFP 1.57400s
#
# 441 Time to perform DFP 0.65300s
#
# 443 Configure Soot DFP 1.79900s
#
# 445 Time to perform DFP 0.79200s
#
# 447 Configure Soot PDG 1.22700s
#
# 449 Time to perform PDG 0.57600s
#
# 451 Configure Soot PDG 1.70000s
#
# 453 Time to perform PDG 0.56400s
#
# 455 Configure Soot Confluence 1 0.78300s
#
# 457 Time to perform Confluence 1 0.48900s
#
# 459 Configure Soot Confluence 2 0.22800s
#
# 461 Time to perform Confluence 2 0.03100s
#
# 463 Configure Soot OA Inter 0.83500s
#
# 465 Time to perform OA Inter 0.92100s
#
# 467 Configure Soot DFP 0.79400s
#
# 469 Time to perform DFP 0.40700s
#
# 471 Configure Soot DFP 0.85400s
#
# 473 Time to perform DFP 0.44200s
#
# 475 Configure Soot PDG 0.78600s
#
# 477 Time to perform PDG 0.51900s
#
# 479 Configure Soot PDG 0.78800s
#
# 481 Time to perform PDG 0.54000s
#
# 483 Configure Soot Confluence 1 0.82500s
#
# 485 Time to perform Confluence 1 0.21600s
#
# 487 Configure Soot Confluence 2 0.28400s
#
# 489 Time to perform Confluence 2 0.00600s
#
# 491 Configure Soot OA Inter 0.86900s
#
# 493 Time to perform OA Inter 0.93900s
#
# 495 Configure Soot DFP 0.81900s
#
# 497 Time to perform DFP 0.20900s
#
# 499 Configure Soot DFP 0.93000s
#
# 501 Time to perform DFP 0.22900s
#
# 503 Configure Soot PDG 0.81400s
#
# 505 Time to perform PDG 0.23900s
#
# 507 Configure Soot PDG 0.82300s
#
# 509 Time to perform PDG 0.23200s
#
# 511 Configure Soot Confluence 1 1.20300s
#
# 513 Time to perform Confluence 1 0.59400s
#
# 515 Configure Soot Confluence 2 0.58300s
#
# 517 Time to perform Confluence 2 0.04200s
#
# 519 Configure Soot OA Inter 1.23600s
#
# 521 Time to perform OA Inter 1.31800s
#
# 523 Configure Soot DFP 1.22900s
#
# 525 Time to perform DFP 0.53800s
#
# 527 Configure Soot DFP 1.20000s
#
# 529 Time to perform DFP 0.59400s
#
# 531 Configure Soot PDG 1.30400s
#
# 533 Time to perform PDG 0.76900s
#
# 535 Configure Soot PDG 1.19700s
#
# 537 Time to perform PDG 0.65400s
#
# 539 Configure Soot Confluence 1 1.35300s
#
# 541 Time to perform Confluence 1 0.82400s
#
# 543 Configure Soot Confluence 2 0.63900s
#
# 545 Time to perform Confluence 2 0.55500s
#
# 547 Configure Soot OA Inter 1.24800s
#
# 549 Time to perform OA Inter 1.35200s
#
# 551 Configure Soot DFP 1.24200s
#
# 553 Time to perform DFP 1.09300s
#
# 555 Configure Soot DFP 1.32600s
#
# 557 Time to perform DFP 2.10300s
#
# 559 Configure Soot PDG 1.36800s
#
# 561 Time to perform PDG 0.81900s
#
# 563 Configure Soot PDG 1.23500s
#
# 565 Time to perform PDG 0.65700s
#
# 567 Configure Soot Confluence 1 1.12500s
#
# 569 Time to perform Confluence 1 0.71500s
#
# 571 Configure Soot Confluence 2 0.60100s
#
# 573 Time to perform Confluence 2 0.33100s
#
# 575 Configure Soot OA Inter 1.20500s
#
# 577 Time to perform OA Inter 1.33100s
#
# 579 Configure Soot DFP 1.16500s
#
# 581 Time to perform DFP 2.82200s
#
# 583 Configure Soot DFP 1.11800s
#
# 585 Time to perform DFP 3.18900s
#
# 587 Configure Soot PDG 1.07700s
#
# 589 Time to perform PDG 0.63600s
#
# 591 Configure Soot PDG 1.09100s
#
# 593 Time to perform PDG 0.64600s
#
# 595 Configure Soot Confluence 1 1.26100s
#
# 597 Time to perform Confluence 1 0.74700s
#
# 599 Configure Soot Confluence 2 0.54600s
#
# 601 Time to perform Confluence 2 0.23400s
#
# 603 Configure Soot OA Inter 1.06100s
#
# 605 Time to perform OA Inter 1.63900s
#
# 607 Configure Soot DFP 1.26600s
#
# 609 Time to perform DFP 2.63000s
#
# 611 Configure Soot DFP 1.10200s
#
# 613 Time to perform DFP 3.13100s
#
# 615 Configure Soot PDG 1.06400s
#
# 617 Time to perform PDG 0.61600s
#
# 619 Configure Soot PDG 1.06400s
#
# 621 Time to perform PDG 0.68600s
#
# 623 Configure Soot Confluence 1 1.08700s
#
# 625 Time to perform Confluence 1 0.23300s
#
# 627 Configure Soot Confluence 2 0.45800s
#
# 629 Time to perform Confluence 2 0.71600s
#
# 631 Configure Soot OA Inter 1.05600s
#
# 633 Time to perform OA Inter 1.13000s
#
# 635 Configure Soot DFP 1.04600s
#
# 637 Time to perform DFP 0.22800s
#
# 639 Configure Soot DFP 1.08400s
#
# 641 Time to perform DFP 0.73600s
#
# 643 Configure Soot PDG 1.01600s
#
# 645 Time to perform PDG 0.24600s
#
# 647 Configure Soot PDG 1.01900s
#
# 649 Time to perform PDG 0.55500s
#
# 651 Configure Soot Confluence 1 1.13800s
#
# 653 Time to perform Confluence 1 0.56600s
#
# 655 Configure Soot Confluence 2 0.52800s
#
# 657 Time to perform Confluence 2 0.10100s
#
# 659 Configure Soot OA Inter 1.18300s
#
# 661 Time to perform OA Inter 1.27200s
#
# 663 Configure Soot DFP 1.13400s
#
# 665 Time to perform DFP 0.60300s
#
# 667 Configure Soot DFP 1.12500s
#
# 669 Time to perform DFP 0.61200s
#
# 671 Configure Soot PDG 1.12700s
#
# 673 Time to perform PDG 0.72100s
#
# 675 Configure Soot PDG 1.26200s
#
# 677 Time to perform PDG 0.73700s
#
# 679 Configure Soot Confluence 1 0.85400s
#
# 681 Time to perform Confluence 1 0.54600s
#
# 683 Configure Soot Confluence 2 0.25600s
#
# 685 Time to perform Confluence 2 0.00500s
#
# 687 Configure Soot OA Inter 0.84500s
#
# 689 Time to perform OA Inter 0.97300s
#
# 691 Configure Soot DFP 0.81200s
#
# 693 Time to perform DFP 0.43000s
#
# 695 Configure Soot DFP 0.80100s
#
# 697 Time to perform DFP 0.19900s
#
# 699 Configure Soot PDG 0.80000s
#
# 701 Time to perform PDG 0.53100s
#
# 703 Configure Soot PDG 0.79800s
#
# 705 Time to perform PDG 0.22100s
#
# Finalizou!
# 707
